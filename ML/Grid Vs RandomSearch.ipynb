# %% [markdown]
# ### Grid Vs Random Search Cross Validation

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/sonar.csv', header=None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# 3  0.0040  0.0117   R
# 4  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
len(df)
# Out:
# 208

# %%
X, y = df.iloc[:, :-1], df.iloc[:, -1]

# %%
# Classification problem 

# Random Forest
#   Parameters to evaluate
#     1. n_estimators
#     2. max_depth
#     3. n_iter

# Use a 1. GridSearchCV 2. RandomSearchCV

# %%
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
#help(RandomForestClassifier)

# %%
clf = RandomForestClassifier()

parameters = {
    'rf': {
        'n_estimators': [10, 20, 30, 40, 50],
        'max_depth': [5, 10, 15],
        'min_samples_split': [40, 30, 20]
    },
    'xgb': {
        'max_depth': [5, 10, 15],
        'max_leaf_nodes': [50, 40, 30, 20]
    }
}

# %%
X.shape, y.shape
# Out:
# ((208, 60), (208,))

# %%
# pip install xgboost==1.5.0

# %%
classifiers = {
    'rf': RandomForestClassifier,
    'xgb': xgb.XGBClassifier
}

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
for clf_name, params in parameters.items():

    clf = classifiers[clf_name]()
    search = GridSearchCV(
        clf,
        params,
        scoring='accuracy',
        cv=5,
        n_jobs=-1)
    search.fit(X.values, y.values)

    print(f"Best Estimator: {search.best_params_}")
    print(f"Best Score: {search.best_score_}")
# Out:
# Best Estimator: {'max_depth': 15, 'min_samples_split': 40, 'n_estimators': 30}
# Best Score: 0.7315911730545877
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best Estimator: {'max_depth': 5, 'max_leaf_nodes': 50}
# Best Score: 0.721835075493612
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/sreejithsreekumar/venvs/transformers/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:35] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:35] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# ...
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:48:55] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:34] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:576:
# Parameters: { "max_leaf_nodes" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [19:52:51] WARNING: /private/var/folders/gh/tdqdcp611d5c7yv0b0np772c0000gn/T/pip-install-nrpw6hnn/xgboost_d4d7bdeebe5e418aaf6d61c258664662/build/temp.macosx-12.0-arm64-3.9/xgboost/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
